# %% [markdown]
# # **Flight Data Analysis Project: Optimizing Air Travel for Sustainability**

# %% [markdown]
# ## **1. Introduction**

# %% [markdown]
# The aviation industry plays a crucial role in global connectivity but also contributes significantly to carbon emissions. With sustainability becoming increasingly important, there's a pressing need to optimize air travel routes, focusing on efficiency and environmental impact. This notebook uses the FlightDataAnalyzer class to explore, analyze, and visualize commercial flight data, aiming to identify opportunities for route optimization and sustainability improvements.
#
# In order to set it up, we first import necessary libraries and our created class. We then initialze the FlightDataAnalyzer instance.

# %%
# Import the FlightDataAnalyzer class and distance calculation function
from FlightAnalyser.class_flight_data import FlightDataAnalyzer
from FlightAnalyser.function_calculate_distance import distance_to

# Initialize the FlightDataAnalyzer instance
flight_data_analyzer = FlightDataAnalyzer()
# Out:
# Data already downloaded

# %% [markdown]
# After initializing FlightDataAnalyzer, data related to airlines, airplanes, airports, and routes is automatically downloaded and stored in corresponding dataframes for analysis.

# %% [markdown]
# **2. Feature Demonstrations**

# %% [markdown]
# ### Plotting Airports Map

# %% [markdown]
# Use plot_airports_map to visualize airports in a specified country.

# %%
flight_data_analyzer.plot_airports_map('Portugal')
# Out:
# c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:212: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Distance Analysis

# %% [markdown]
# Demonstrate distance_analysis to plot the distribution of flight distances.

# %%
flight_data_analyzer.distance_analysis()

# %% [markdown]
# ### Plotting Flights from an Airport

# %% [markdown]
# Utilize plot_flights_from_airport to show flights departing from a specific airport.

# %%
flight_data_analyzer.plot_flights_from_airport('Madrid Barajas Airport')
# Out:
# Error: Airport 'Madrid Barajas Airport' does not exist.

# %% [markdown]
# ### Most Used Airplane Models

# %% [markdown]
# Use plot_most_used_airplane_models to display the most popular airplane models.

# %%
flight_data_analyzer.plot_most_used_airplane_models(n=5)

# %% [markdown]
# ### Plotting Flights from a Country

# %% [markdown]
# Demonstrate plot_flights_from_country for visualizing flights from all airports in a specified country.

# %%
flight_data_analyzer.plot_flights_from_country('Germany')

# %% [markdown]
# ### Short Haul Routes Analysis

# %% [markdown]
# Showcase calculate_short_haul_routes to analyze potential short-haul routes that could be more sustainable.

# %%
short_haul_analysis = flight_data_analyzer.calculate_short_haul_routes('Italy')
short_haul_analysis.head()
# Out:
# c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:544: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                              Name_source Source airport  \
# 92                   Pantelleria Airport            PNL
# 91                   Pantelleria Airport            PNL
# 45                 Lamezia Terme Airport            SUF
# 113           Falcone–Borsellino Airport            PMO
# 345  Leonardo da Vinci–Fiumicino Airport            FCO
#
#                           Name_Destination Destination airport    Distance  \
# 92   Vincenzo Florio Airport Trapani-Birgi                 TPS  130.103212
# ...

# %% [markdown]
# ### Aircraft Information

# %% [markdown]
# Implement aircraft_info to provide detailed specifications of an aircraft, illustrating the integration with the OpenAI API.

# %%
flight_data_analyzer.aircraft_info('Boeing 747')
# Out:
# | Information | Boeing 747 |
#
# | Here are some of the key specifications for the Boeing 747-8, which is the latest variant of the 747:
#
# - Length: 250 feet, 2 inches
# - Wingspan: 224 feet, 7 inches
# - Height: 63 feet, 6 inches
# - Maximum takeoff weight: 987,000 pounds
# - Maximum range: 7,730 nautical miles
# - Maximum cruising speed: Mach 0.855
# - Seating capacity: Up to 467 passengers in a typical three-class configuration
#
# These specifications can vary depending on the specific variant of the Boeing 747 and any modifications made by the airline or operator. | |
#
#
# | --------- | ----- |

# %% [markdown]
# Error Handling: If the model that the user types in is not encountered, the user is then informed that the requested model does not exist and instead, a similar model is then suggested.

# %%
flight_data_analyzer.aircraft_info("Boeing 7899")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 flight_data_analyzer.aircraft_info("Boeing 7899")
#
# File c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:635, in FlightDataAnalyzer.aircraft_info(self, aircraft_name)
#     632 if aircraft_name not in self.airplanes["Name"].unique():
#     633     #Get most similiar string based on input from aircrafts list
#     634     most_similar = self.get_most_similar_aircraft(aircraft_name)
# --> 635     raise ValueError(f"The aircraft name {aircraft_name} does not exist. Did you mean: {most_similar}" )
#     636 else:
#     637     #print(self.OPENAI_API_KEY)
#     638     client = OpenAI(api_key= OPENAI_API_KEY)
#
# ValueError: The aircraft name Boeing 7899 does not exist. Did you mean: Boeing 787-9

# %% [markdown]
# ### Airport information

# %% [markdown]
# Implement airport_info to provide detailed specifications of an aircraft, illustrating the integration with the OpenAI API.

# %%
flight_data_analyzer.airport_info("Lisbon Humberto Delgado Airport")
# Out:
# | Information | Lisbon Humberto Delgado Airport |
#
# | Lisbon Humberto Delgado Airport, also known as Lisbon Airport, is the main international airport serving the city of Lisbon, Portugal. Here are some specifications of the airport:
#
# 1. Location: The airport is located about 7 km (4.3 miles) north of Lisbon city center.
#
# 2. IATA code: LIS
#
# 3. ICAO code: LPPT
#
# 4. Elevation: 114 meters (374 feet) above sea level
#
# 5. Number of terminals: Lisbon Airport has two passenger terminals - Terminal 1 (the main terminal) and Terminal 2 (for low-cost carriers)
#
# 6. Runways: The airport has two runways:
#    - Runway 03/21: 3,412 meters in length
#    - Runway 17/35: 2,550 meters in length
#
# 7. Passenger traffic: Lisbon Humberto Delgado Airport is one of the busiest airports in southern Europe, serving millions of passengers each year.
#
# ...

# %% [markdown]
# Error Handling: If the model that the user types in is not encountered, the user is then informed that the requested model does not exist and instead, a similar model is then suggested.

# %% [markdown]
# **Distance Calculation Function**

# %% [markdown]
# Demonstrate the utility of the distance_to function, highlighting its importance in analyzing flight distances.

# %%
vienna_lisbon_distance = distance_to(flight_data_analyzer, "LOWW", "LPPT") 
print("The distance from Vienna to Lisbon is: ", vienna_lisbon_distance)
# Out:
# The distance from Vienna to Lisbon is:  2305.0083667849885

# %% [markdown]
# **3. Understanding the Landscape**

# %% [markdown]
# **Airports Distribution**
#
# First, we visualize the distribution of airports in countries with significant air traffic volumes, such as the United States, China, and Spain, to understand the geographical spread of air travel infrastructure.

# %%
flight_data_analyzer.plot_airports_map('United States')
flight_data_analyzer.plot_airports_map('China')
flight_data_analyzer.plot_airports_map('Spain')
# Out:
# c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:212: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:212: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:212: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# **Flight Distance Analysis**
#
# We analyze the distribution of flight distances to understand the range of air travel. This analysis helps identify the prevalence of short-haul vs. long-haul flights, which have different environmental impacts.

# %%
flight_data_analyzer.distance_analysis()

# %% [markdown]
# **4. Identifying Opportunities for Optimization**

# %% [markdown]
# **Analyzing Flights from Major Airports**
#
# By examining flights departing from major airports, we can identify key hubs and their role in global connectivity. We focus on airports like JFK (New York) and Heathrow (London), analyzing the distribution of their flights.

# %%
flight_data_analyzer.plot_flights_from_airport("John F Kennedy International Airport", internal = True)
flight_data_analyzer.plot_flights_from_airport('London Heathrow Airport', limit = 500)

# %% [markdown]
# It is also useful to do this for local hubs, to understand what flights are long haul and what are short haul based on our color coding.

# %%
flight_data_analyzer.plot_flights_from_airport("Cologne Bonn Airport")

# %% [markdown]
# **Most Used Airplane Models**
#
# Understanding which airplane models are most used in the industry can highlight models that might be candidates for fuel efficiency improvements or replacements with more sustainable alternatives.

# %%
flight_data_analyzer.plot_most_used_airplane_models(n=10)

# %% [markdown]
# **5. Focusing on Sustainability**

# %% [markdown]
# **Short-Haul Route Optimization**
#
# Short-haul flights are prime candidates for replacement with more sustainable travel options like high-speed rail. We analyze short-haul routes in Spain, a country with both a significant number of airports and an extensive high-speed rail network.

# %%
short_haul_analysis = flight_data_analyzer.calculate_short_haul_routes('Spain', cutoff_distance=1000)
# Out:
# c:\Users\weish\OneDrive\Dokumente\Masters\S2\T3\Web and Cloud Computing\ADPRO_Project\FlightAnalyser\class_flight_data.py:544: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# This analysis could inform policies or investments aimed at reducing the reliance on short-haul flights in favor of more sustainable transportation modes.

# %% [markdown]
# **Aircraft Sustainability Analysis**
#
# To further our sustainability efforts, we look into the specifications of popular aircraft models to assess their fuel efficiency and potential for emissions reduction.

# %%
flight_data_analyzer.aircraft_info('Airbus A320')
flight_data_analyzer.aircraft_info('Boeing 737')
# Out:
# | Information | Airbus A320 |
#
# | The Airbus A320 is a short- to medium-range narrow-body commercial passenger jet airliner. Here are some general specifications for the Airbus A320:
#
# - Length: 37.57 meters
# - Wingspan: 34.1 meters
# - Height: 11.76 meters
# - Maximum Takeoff Weight: 78,000 kg
# - Range: 3,300 - 6,100 km, depending on model
# - Cruise Speed: approximately 840 km/h
# - Maximum Seating Capacity: up to 180 passengers
# - Engines: Two CFM International CFM56 or International Aero Engines V2500 engines
#
# The A320 family includes several variants, such as the A318, A319, A321, and A320neo, with differing sizes, ranges, and fuel efficiencies. Each model offers unique capabilities to cater to different airline requirements. | |
#
#
# | --------- | ----- |
#
# | Information | Boeing 737 |
#
# | The Boeing 737 is a popular and versatile narrow-body aircraft produced by Boeing Commercial Airplanes. Here are some general specifications for the Boeing 737:
#
# ...

# %% [markdown]
# **6. Conclusion: Path Towards Sustainable Aviation**

# %% [markdown]
# This notebook has leveraged the FlightDataAnalyzer class to explore commercial airflight data with a focus on sustainability. By analyzing the distribution of airports, flight distances, and the usage of airplane models, we've identified opportunities for route optimization and environmental impact reduction.
#
# Our findings suggest significant potential for reducing emissions through optimizing short-haul routes and reevaluating the use of certain airplane models. The transition towards more sustainable modes of transportation, particularly for short-haul flights, could greatly reduce the aviation industry's carbon footprint.
